# %% [markdown]
# # **SORTEO DE GRUPOS**

# %%
import random as rd
import time as tm
from IPython.display import display, clear_output
import pandas as pd
from IPython.display import HTML
import ipywidgets as widgets

# Lista de 12 participantes
PARTICIPANTES = ['Armada', 'Coquina', 'Puche', 'Fale', 'Gonzo', 'Kero', 'Kike', 'Lope', 'Palop', 'Papu', 'Ruso', 'Tony', 'Suertudo', 'Suertudo', 'Suertudo', 'Suertudo']

# Función que se ejecuta al hacer clic en el botón
def iniciar_sorteo(b):
    print("Sorteo iniciado...")
    sorteo_dinamico()
    
# Reiniciar los grupos
lado_A = []
lado_B = []

# Función que muestra la tabla en proceso
def mostrar_progreso():
    # Crear DataFrame con los grupos (rellenar con espacios vacíos para mantener el formato)
    max_len = max(len(lado_A), len(lado_B))
    data = {
        "Equipo A": lado_A + [""] * (max_len - len(lado_A)),
        "Equipo B": lado_B + [""] * (max_len - len(lado_B))
    }
    df = pd.DataFrame(data)
    
    # Mostrar la tabla con estilo futurista
    clear_output(wait=True)
    display(HTML(df.to_html(index=False, classes='futuristic-table')))
    print("Sorteo en progreso...")

# Función que realiza el sorteo con tabla dinámica
def sorteo_dinamico():
    # Mezclar los participantes
    rd.shuffle(PARTICIPANTES)
    
    # Limpiar los grupos
    lado_A.clear()
    lado_B.clear()

    # Simular el sorteo con un retardo, actualizando la tabla en tiempo real
    for i, participante in enumerate(PARTICIPANTES):
        if i % 2 == 0:
            lado_A.append(participante)
        else:
            lado_B.append(participante)
        
        # Mostrar el progreso de la tabla
        mostrar_progreso()
        
        # Pausa de 2 segundos
        tm.sleep(2)
    
    # Mostrar el resultado del sorteo y devolver el DataFrame
    df = mostrar_sorteo()
    
    # Guardar el DataFrame en un archivo Excel
    df.to_excel("octavos_copa.xlsx", index=False)
    print("El sorteo ha finalizado y los enfrentamientos se han guardado en 'octavos_copa.xlsx'.")
    return df

# Función para mostrar el sorteo
def mostrar_sorteo():
    clear_output(wait=True)
    # Crear DataFrame con los grupos
    data = {
        "Equipo A": lado_A,
        "Equipo B": lado_B
    }
    df = pd.DataFrame(data)
    
    # Mostrar la tabla con estilo futurista
    print("Enfrentamientos Octavos copa:")
    display(HTML(df.to_html(index=False, classes='futuristic-table')))
    
    return df
    

# Estilo futurista para la tabla
display(HTML("""
<style>
.futuristic-table {
    font-family: 'Courier New', monospace;
    color: #00FF00;
    background-color: #000000;
    border: 1px solid #00FF00;
    border-collapse: collapse;
    width: 50%;
    margin-left: auto;
    margin-right: auto;
}
.futuristic-table th, .futuristic-table td {
    border: 1px solid #00FF00;
    padding: 8px;
    text-align: center;
}
.futuristic-table th {
    background-color: #001f00;
}
</style>
"""))
# Out:
# <style>
# .futuristic-table {
#     font-family: 'Courier New', monospace;
#     color: #00FF00;
#     background-color: #000000;
#     border: 1px solid #00FF00;
#     border-collapse: collapse;
#     width: 50%;
#     margin-left: auto;
#     margin-right: auto;
# }
# .futuristic-table th, .futuristic-table td {
#     border: 1px solid #00FF00;
#     padding: 8px;
#     text-align: center;
# }
# .futuristic-table th {
#     background-color: #001f00;
# }
# </style>

# %%
# Crear el botón
boton_sorteo = widgets.Button(
    description="Iniciar Sorteo",
    disabled=False,
    button_style='danger',  # 'success', 'info', 'warning', 'danger' o ''
    tooltip='Haz clic para iniciar el sorteo',
    icon='check'  # (opcional) Agregar un icono de FontAwesome
)

# Asignar la función al evento de clic del botón
boton_sorteo.on_click(iniciar_sorteo)

# Mostrar el botón
display(boton_sorteo)
# Out:
# Enfrentamientos Octavos copa:
# <table border="1" class="dataframe futuristic-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Equipo A</th>
#       <th>Equipo B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Gonzo</td>
#       <td>Fale</td>
#     </tr>
#     <tr>
#       <td>Suertudo</td>
#       <td>Papu</td>
#     </tr>
#     <tr>
#       <td>Palop</td>
#       <td>Tony</td>
#     </tr>
#     <tr>
#       <td>Ruso</td>
#       <td>Coquina</td>
#     </tr>
#     <tr>
#       <td>Suertudo</td>
#       <td>Suertudo</td>
#     </tr>
#     <tr>
#       <td>Kike</td>
#       <td>Lope</td>
#     </tr>
#     <tr>
#       <td>Kero</td>
#       <td>Suertudo</td>
#     </tr>
#     <tr>
#       <td>Puche</td>
#       <td>Armada</td>
#     </tr>
#   </tbody>
# </table>
# El sorteo ha finalizado y los enfrentamientos se han guardado en 'octavos_copa.xlsx'.

# %%
import random as rd
import time as tm
from IPython.display import display, clear_output
import pandas as pd
from IPython.display import HTML
import ipywidgets as widgets

# Lista de 12 participantes
PARTICIPANTES = ['Armada', 'Coquina', 'Gonzo', 'Kero', 'Lope', 'Papu', 'Tony', 'Suertudo']

# Función que se ejecuta al hacer clic en el botón
def iniciar_sorteo(b):
    print("Sorteo iniciado...")
    sorteo_dinamico()
    
# Reiniciar los grupos
lado_A = []
lado_B = []

# Función que muestra la tabla en proceso
def mostrar_progreso():
    # Crear DataFrame con los grupos (rellenar con espacios vacíos para mantener el formato)
    max_len = max(len(lado_A), len(lado_B))
    data = {
        "Equipo A": lado_A + [""] * (max_len - len(lado_A)),
        "Equipo B": lado_B + [""] * (max_len - len(lado_B))
    }
    df = pd.DataFrame(data)
    
    # Mostrar la tabla con estilo futurista
    clear_output(wait=True)
    display(HTML(df.to_html(index=False, classes='futuristic-table')))
    print("Sorteo en progreso...")

# Función que realiza el sorteo con tabla dinámica
def sorteo_dinamico():
    # Mezclar los participantes
    rd.shuffle(PARTICIPANTES)
    
    # Limpiar los grupos
    lado_A.clear()
    lado_B.clear()

    # Simular el sorteo con un retardo, actualizando la tabla en tiempo real
    for i, participante in enumerate(PARTICIPANTES):
        if i % 2 == 0:
            lado_A.append(participante)
        else:
            lado_B.append(participante)
        
        # Mostrar el progreso de la tabla
        mostrar_progreso()
        
        # Pausa de 2 segundos
        tm.sleep(2)
    
    # Mostrar el resultado del sorteo y devolver el DataFrame
    df = mostrar_sorteo()
    
    # Guardar el DataFrame en un archivo Excel
    df.to_excel("cuartos_copa.xlsx", index=False)
    print("El sorteo ha finalizado y los enfrentamientos se han guardado en 'cuartos_copa.xlsx'.")
    return df

# Función para mostrar el sorteo
def mostrar_sorteo():
    clear_output(wait=True)
    # Crear DataFrame con los grupos
    data = {
        "Equipo A": lado_A,
        "Equipo B": lado_B
    }
    df = pd.DataFrame(data)
    
    # Mostrar la tabla con estilo futurista
    print("Enfrentamientos Cuartos copa:")
    display(HTML(df.to_html(index=False, classes='futuristic-table')))
    
    return df
    

# Estilo futurista para la tabla
display(HTML("""
<style>
.futuristic-table {
    font-family: 'Courier New', monospace;
    color: #00FF00;
    background-color: #000000;
    border: 1px solid #00FF00;
    border-collapse: collapse;
    width: 50%;
    margin-left: auto;
    margin-right: auto;
}
.futuristic-table th, .futuristic-table td {
    border: 1px solid #00FF00;
    padding: 8px;
    text-align: center;
}
.futuristic-table th {
    background-color: #001f00;
}
</style>
"""))
# Out:
# <style>
# .futuristic-table {
#     font-family: 'Courier New', monospace;
#     color: #00FF00;
#     background-color: #000000;
#     border: 1px solid #00FF00;
#     border-collapse: collapse;
#     width: 50%;
#     margin-left: auto;
#     margin-right: auto;
# }
# .futuristic-table th, .futuristic-table td {
#     border: 1px solid #00FF00;
#     padding: 8px;
#     text-align: center;
# }
# .futuristic-table th {
#     background-color: #001f00;
# }
# </style>

# %%
# Crear el botón
boton_sorteo = widgets.Button(
    description="Iniciar Sorteo",
    disabled=False,
    button_style='danger',  # 'success', 'info', 'warning', 'danger' o ''
    tooltip='Haz clic para iniciar el sorteo',
    icon="check" # (opcional) Agregar un icono de FontAwesome
)

# Asignar la función al evento de clic del botón
boton_sorteo.on_click(iniciar_sorteo)

# Mostrar el botón
display(boton_sorteo)
# Out:
# <table border="1" class="dataframe futuristic-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Equipo A</th>
#       <th>Equipo B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Tony</td>
#       <td>Papu</td>
#     </tr>
#     <tr>
#       <td>Coquina</td>
#       <td>Kero</td>
#     </tr>
#     <tr>
#       <td>Armada</td>
#       <td>Suertudo</td>
#     </tr>
#     <tr>
#       <td>Gonzo</td>
#       <td>Lope</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Crear el cuadro de eliminatorias
def mostrar_cuadro_eliminatorias():
    # Crear DataFrame con los partidos
    data = {
        "Partido Lado A": [f"{lado_A[i]} vs {lado_B[i]}" for i in range(2)],
        "Partido Lado B": [f"{lado_A[i+2]} vs {lado_B[i+2]}" for i in range(2)]
    }
    df = pd.DataFrame(data)
    
    # Mostrar la tabla con estilo futurista
    print("Cuadro de eliminatorias:")
    display(HTML(df.to_html(index=False, classes='futuristic-table')))
    
    
# Llamar a la función para mostrar el cuadro
mostrar_cuadro_eliminatorias()
# Out:
# Cuadro de eliminatorias:
# <table border="1" class="dataframe futuristic-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Partido Lado A</th>
#       <th>Partido Lado B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Tony vs Papu</td>
#       <td>Armada vs Suertudo</td>
#     </tr>
#     <tr>
#       <td>Coquina vs Kero</td>
#       <td>Gonzo vs Lope</td>
#     </tr>
#   </tbody>
# </table>
